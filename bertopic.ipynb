# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/mads_thesis')
# !pwd
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/mads_thesis

# %% [markdown]
# Install required libraries

# %%
# !pip install bertopic
# !pip install octis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.29)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.3)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.24.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.13.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.30.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: octis in /usr/local/lib/python3.10/dist-packages (1.12.1)
# Requirement already satisfied: gensim==4.2.0 in /usr/local/lib/python3.10/dist-packages (from octis) (4.2.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from octis) (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from octis) (1.5.3)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from octis) (3.5.2)
# Requirement already satisfied: scikit-learn==0.24.2 in /usr/local/lib/python3.10/dist-packages (from octis) (0.24.2)
# Requirement already satisfied: scikit-optimize>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from octis) (0.9.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from octis) (3.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from octis) (2.0.1+cu118)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from octis) (1.23.5)
# Requirement already satisfied: libsvm in /usr/local/lib/python3.10/dist-packages (from octis) (3.23.0.4)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from octis) (2.2.4)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (from octis) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from octis) (2.27.1)
# Requirement already satisfied: tomotopy in /usr/local/lib/python3.10/dist-packages (from octis) (0.12.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.2.0->octis) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.2.0->octis) (6.3.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2->octis) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2->octis) (3.1.0)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize>=0.8.1->octis) (23.5.9)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask->octis) (2.3.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask->octis) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask->octis) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask->octis) (8.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->octis) (2.8.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->octis) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->octis) (4.65.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->octis) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->octis) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->octis) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->octis) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->octis) (3.4)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->octis) (4.30.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->octis) (0.15.2+cu118)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->octis) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->octis) (0.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->octis) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->octis) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->octis) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->octis) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->octis) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->octis) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->octis) (16.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (0.10.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (1.10.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->octis) (3.3.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->octis) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->octis) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask->octis) (2.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->octis) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->octis) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->octis) (0.0.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->octis) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->octis) (0.3.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->octis) (1.3.0)

# %% [markdown]
# Import Libaries

# %%
from bertopic import BERTopic
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.representation import MaximalMarginalRelevance
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel
from octis.evaluation_metrics.diversity_metrics import TopicDiversity
import pandas as pd
import numpy as np

# %% [markdown]
# Create BERTopic model

# %%
def bertopic_model(docs):
    ctidf_model = ClassTfidfTransformer(reduce_frequent_words=True)
    topic_model = BERTopic(nr_topics="auto",
                           ctfidf_model=ctidf_model,
                           calculate_probabilities=False)
    topics, probs = topic_model.fit_transform(docs)
    return topic_model, topics, probs

# %% [markdown]
# Create visualization function

# %%
def visualize_model(topic_model):
    print(topic_model.get_topic_info())
    print('\n\n\n')
    for i in range(0, 10):
        print(topic_model.get_topic(i))

# %% [markdown]
# Evaluate Model

# %%
def evaluate_model(topic_model, docs, topics, probs):
    # Topic Coherence
    # Preprocess Documents
    documents = pd.DataFrame({"Document": docs,
                              "ID": range(len(docs)),
                              "Topic": topics})
    documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ' '.join})
    cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

    # Extract vectorizer and analyzer from BERTopic
    vectorizer = topic_model.vectorizer_model
    analyzer = vectorizer.build_analyzer()

    # Extract features for Topic Coherence evaluation
    words = vectorizer.get_feature_names()
    tokens = [analyzer(doc) for doc in cleaned_docs]
    dictionary = corpora.Dictionary(tokens)
    corpus = [dictionary.doc2bow(token) for token in tokens]
    topic_words = [[words for words, _ in topic_model.get_topic(topic)]
                   for topic in range(len(set(topics))-1)]

    # Evaluate
    coherence_model = CoherenceModel(topics=topic_words,
                                    texts=tokens,
                                    corpus=corpus,
                                    dictionary=dictionary,
                                    coherence='c_v')
    coherence = coherence_model.get_coherence()
    print(f'Coherence Score: {coherence}')

    # Topic Diversity
    diversity = TopicDiversity(topk=10)
    topics = pd.DataFrame(topic_model.get_topic_info()['Representation']).rename(columns={'Representation': 'topics'})
    model_diversity = diversity.score(topics)
    print(f'\nDiversity is: {model_diversity}\n')

# %% [markdown]
# Load data

# %%
train_data = pd.read_pickle('Video_Games_final_train.pkl.gz')
dev_data = pd.read_pickle('Video_Games_final_dev.pkl.gz')
test_data = pd.read_pickle('Video_Games_final_test.pkl.gz')
df = np.array(pd.concat([train_data['review_text'], dev_data['review_text'], test_data['review_text']]))

# %% [markdown]
# Create model

# %%
model, topics, probs = bertopic_model(df)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:01<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %% [markdown]
# Run visualization

# %%
visualize_model(model)
# Out:
#      Topic  Count                                  Name  \
# 0       -1  12409                   -1_buy_me_fun_after
# 1        0  13272               0_xbox_wii_story_system
# 2        1   1089              1_sims_sim_zoo_expansion
# 3        2    435             2_madden_nba_football_nfl
# 4        3    409    3_flight_simulator_aircraft_planes
# ..     ...    ...                                   ...
# 142    141     11              141_ac1_ac2_turbine_beta
# 143    142     11        142_buffy_willow_slayer_xander
# 144    143     10   143_airport_airline_tycoon_terminal
# 145    144     10  144_sidewinder_joystick_xp_joysticks
# 146    145     10   145_cooking_mama_ingredients_recipe
#
#                                         Representation  \
# 0    [buy, me, fun, after, itdont, then, playing, l...
# 1    [xbox, wii, story, system, final, characters, ...
# 2    [sims, sim, zoo, expansion, maxis, dog, animal...
# 3    [madden, nba, football, nfl, basketball, ncaa,...
# 4    [flight, simulator, aircraft, planes, fly, sim...
# ..                                                 ...
# 142  [ac1, ac2, turbine, beta, ac, daoc, dereth, cr...
# 143  [buffy, willow, slayer, xander, ethan, vampire...
# 144  [airport, airline, tycoon, terminal, airlines,...
# 145  [sidewinder, joystick, xp, joysticks, migrated...
# 146  [cooking, mama, ingredients, recipe, cookies, ...
#
#                                    Representative_Docs
# 0    [Overall, the game is definately the best WW I...
# 1    [If one thing can be said about Doom 3, it's t...
# 2    [On the Gamecube, Animal Crossing was a hit. I...
# 3    [There's no disputing that EA owns the lion's ...
# 4    [I am in love with aviation, and therefore FS ...
# ..                                                 ...
# 142  [Well, I made it through about 40 reviews befo...
# 143  [Buffy The Vampire Slayer is not only the best...
# 144  [I LOVED the original Airport Tycoon and got h...
# 145  [I've owned this stick for years and it always...
# 146  [I like the concept for this game. You have to...
#
# [147 rows x 5 columns]
#
#
#
#
# [('xbox', 0.07519705177574505), ('wii', 0.07385349386725461), ('story', 0.07337763754698955), ('system', 0.07307594293806331), ('final', 0.07305057115097062), ('characters', 0.0721931747342511), ('halo', 0.07180243395327938), ('fantasy', 0.07179786952191029), ('360', 0.07131179090843856), ('ps3', 0.07079404540133201)]
# [('sims', 0.28545945001992434), ('sim', 0.19436594396642332), ('zoo', 0.16384350312948973), ('expansion', 0.1536464350109074), ('maxis', 0.152099636299093), ('dog', 0.15068519214064413), ('animals', 0.15005795124521173), ('animal', 0.14337746383235056), ('pets', 0.14330107047856386), ('simcity', 0.13901839876375452)]
# [('madden', 0.29489359236747476), ('nba', 0.2596409004915598), ('football', 0.24985690135963662), ('nfl', 0.21452488443476309), ('basketball', 0.20157473226482356), ('ncaa', 0.19503451631200705), ('espn', 0.1843251963440942), ('ea', 0.16959229084529823), ('college', 0.16411922137927445), ('ball', 0.1615111897433083)]
# [('flight', 0.34378553369536224), ('simulator', 0.2651942014158408), ('aircraft', 0.24873178788205796), ('planes', 0.2363292319345911), ('fly', 0.21390132832365014), ('sim', 0.20494866081234178), ('plane', 0.2005811985161903), ('flying', 0.1948106210679756), ('fs', 0.19287435437926206), ('pilot', 0.17754110221888875)]
# [('controller', 0.33036220189160975), ('joystick', 0.30788707520671343), ('buttons', 0.2640939401207343), ('throttle', 0.23194664757450406), ('stick', 0.23021427254254984), ('controllers', 0.21696039196542766), ('rudder', 0.19176348929577944), ('sticks', 0.1879256369875626), ('dpad', 0.1807832184715617), ('joysticks', 0.18074332336947466)]
# [('pokemon', 0.5092861427101033), ('pikachu', 0.28945420947418754), ('ruby', 0.22808280402507064), ('pokeacutemon', 0.21934024692612392), ('sapphire', 0.2154746285535887), ('trainers', 0.2022363352565142), ('gym', 0.201698637776081), ('catch', 0.19568407763447146), ('pikmin', 0.1949056532220374), ('silver', 0.18565087446439396)]
# [('drm', 0.4693881798824774), ('spore', 0.34306833864174174), ('ea', 0.25948381231913903), ('securom', 0.20682879454822603), ('installs', 0.20618907380444615), ('install', 0.20219031476255211), ('activation', 0.20135776005957828), ('draconian', 0.18155517475254396), ('piracy', 0.18146986699508189), ('customers', 0.17160611246390045)]
# [('ordered', 0.33578977396328047), ('amazon', 0.3109013217844007), ('shipping', 0.2847718742209366), ('shipped', 0.27864888874024296), ('order', 0.24450670708784095), ('delivery', 0.2414043433229169), ('item', 0.22799650125381174), ('received', 0.2266375840183246), ('product', 0.21975084761711428), ('preorder', 0.2175596674944317)]
# [('baseball', 0.4022931730406567), ('mlb', 0.29222296103869333), ('mvp', 0.2759886237240813), ('pitching', 0.2376706132552504), ('batting', 0.23704377225037007), ('pitch', 0.2335820571425844), ('pitcher', 0.22653070535878983), ('fielding', 0.20564195829100423), ('triple', 0.20548001715622705), ('pitchers', 0.20241852070757366)]
# [('rides', 0.32869411378742086), ('coaster', 0.3260950473390301), ('tycoon', 0.3253307444703266), ('park', 0.3099966230835819), ('roller', 0.3093504934950773), ('coasters', 0.2784518594384599), ('rct', 0.2615196920240006), ('rollercoaster', 0.24918514314362414), ('railroad', 0.23322849989295705), ('ride', 0.2199643111520204)]

# %% [markdown]
# Evaluate model

# %%
evaluate_model(model, df, topics, probs)
# Out:
# Coherence Score: 0.6837356366223892
#
# Diversity is: 0.8965986394557823
